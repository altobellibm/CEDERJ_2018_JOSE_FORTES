# %% [markdown]
# # Exemplo de Plotagem de Gráficos em Python usando MatPlotLib

# %% [markdown]
# # Mapa de Calor (Heat Map)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Mapa de calor Simples

# %%
# Create data
x = np.random.randn(4096)
y = np.random.randn(4096)
 
# Create heatmap
heatmap, xedges, yedges = np.histogram2d(x, y, bins=(64,64))
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]
 
# Plot heatmap
plt.clf()
plt.title('Exemplo de Mapa de Calor')
plt.ylabel('y')
plt.xlabel('x')
plt.imshow(heatmap, extent=extent)
plt.show()
# Out:
# [-2.16444116  0.16296397 -2.02801744 ...  0.5894033   1.30325777
#   2.07309276]
# [ 1.11952288  0.38636109  0.74736471 ... -1.11552179 -2.25523089
#  -0.09298029]
